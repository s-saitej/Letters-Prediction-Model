# %%
import pandas as pd
import matplotlib.pyplot

# %%
data = pd.read_csv('letterdata.csv')

# %%
print(data)
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# 5          S     4    11      5       8      3     8     8      6      9
# 6          B     4     2      5       4      4     8     7      6      6
# 7          A     1     1      3       2      1     8     2      2      2
# 8          J     2     2      4       4      2    10     6      2      6
# 9          M    11    15     13       9      7    13     2      6      2
# 10         X     3     9      5       7      4     8     7      3      8
# 11         O     6    13      4       7      4     6     7      6      3
# ...

# %%
x = data.iloc[:,1:]

# %%
y = data.iloc[:,:1]

# %%
x.isnull().any()
# Out:
# xbox      False
# ybox      False
# width     False
# height    False
# onpix     False
# xbar      False
# ybar      False
# x2bar     False
# y2bar     False
# xybar     False
# x2ybar    False
# xy2bar    False
# xedge     False
# xedgey    False
# yedge     False
# yedgex    False
# dtype: bool

# %%
y.isnull().any()
# Out:
# letter    False
# dtype: bool

# %%
from sklearn import model_selection

# %%
train_data,test_data,train_target,test_target = model_selection.train_test_split(x,y)

# %%
train_data
# Out:
#        xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 6604      3     9      4       6      3     3     5      1      8      3
# 6089      1     3      2       2      0     7     7      0      7     13
# 1943      5     5      6       8      2     6     7      7     10      8
# 11983     5     9      7       7      6     8     8      7      6      7
# 12937     3     7      4       5      2     7     8      3     12      8
# 11124     3     6      4       4      2     8     7      7      4     10
# 15541     2     6      4       4      5    10     7      4      5      7
# 6463      8    10      9       8      6     4     8      5      8      9
# 19327     3     4      4       7      2     9     8      6      9      4
# 3585      6     9      9       6      4     5     8      2      8     11
# 17174     5    10      6       7      3     8     8      9      8      7
# 16456     2     8      3       5      1     1    13      4      3     12
# ...

# %%
test_data
# Out:
#        xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 1975      3     5      6       4      3     6     8      2      9     11
# 9047      2     1      3       2      2     6     7      4      7      7
# 7067      4     8      6       6      7     6     7      3      6      6
# 14689     4    11      6       9      4     7    11      2      4      6
# 744       2     1      3       2      2     8     7      7      7      7
# 249       5     9      7       7      6     7     9      5      6     10
# 17112     5     8      6       6      4     8     8      7      7     10
# 8593      2     3      4       4      1     9    10      3      2      5
# 4098      4    11      6       8      3     4     4      1     10      6
# 7197      7    11      8       8      7     8     7      8      5      9
# 10749     3     7      5       5      7     8     9      5      1      7
# 7571      4    10      7       8      4     9     7      0      8      9
# ...

# %%
from sklearn import svm

# %%
classification = svm.SVC(kernel = 'rbf', C=1, gamma = 10)

# %%
fitting = classification.fit(train_data,train_target)
# Out:
# D:\Installers\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
result = classification.predict(test_data)
